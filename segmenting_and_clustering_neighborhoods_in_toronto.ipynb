# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto
# Applied Data Science Capstone week 3 Peer graded assignment
#
# Neville Yoon

# %%
import pandas as pd
import numpy as np
import requests
#!conda install -c conda-forge beautifulsoup4 --yes 
from bs4 import BeautifulSoup
#!conda install -c anaconda lxml --yes

# %% [markdown]
# # Section 1: Scrape the table from the Wikipedia page into a DataFrame

# %% [markdown]
# Use BeautifulSoup to scrape the web page and convert the table into a Pandas DataFrame

# %%
# Read the html page into a BeautifulSoup object
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(url).text
doc = BeautifulSoup(page,'lxml')

#Extract the table and convert to a DataFrame
tables = doc.find('table')
df = pd.read_html(str(tables))[0]
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                                NaN
#
# [180 rows x 3 columns]

# %% [markdown]
# ### Inspect and clean the data

# %%
# look for rows where Borough is 'Not assigned'
sum(df['Borough'].str.upper() == 'NOT ASSIGNED')
# Out:
# 77

# %%
# remove rows where Borough is 'Not assigned'
df_filtered = df[df['Borough']!= 'Not assigned'].reset_index(drop=True)
df_filtered
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
# look for rows where Neighborhood is 'Not assigned'
sum(df_filtered['Neighborhood'].str.upper() == 'NOT ASSIGNED')
# Out:
# 0

# %%
# look for rows where Neighborhod is empty
sum(df_filtered['Neighborhood'].isnull())
# Out:
# 0

# %% [markdown]
# ## Answer #1:

# %%
df_filtered.shape
# Out:
# (103, 3)

# %% [markdown]
# # Section 2: Geocode Postal Codes

# %% [markdown]
# First let's attempt to get latitude and longitude coordinates for the postal codes using geocoder.

# %%
import io
import geocoder # import geocoder

def get_coords(postal_code):
    '''Get latitude and longitude coordinates for a Toronto Postal Code'''
    print("attempting to get coordinates for {}".format(postal_code),end="")
    max_tries = 10
    lat_lng_coords = None
    i = 1
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        if i > max_tries:
            print("Failed to get coordinates",end="")
            break
        print(".",end="")
        g = geocoder.osm('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
        i += 1
    print("")
    return lat_lng_coords

# %%
postal_codes = df_filtered['Postal Code'].tolist()

latitudes = []
longitudes = []
for pc in postal_codes:
    coords = get_coords(pc)
    if coords:
        latitudes.append(coords[0])
        longitudes.append(coords[1])
    else:
        latitudes.append(None)
        longitudes.append(None)
# Out:
# attempting to get coordinates for M3A.
# attempting to get coordinates for M4A..........Failed to get coordinates
# attempting to get coordinates for M5A..........Failed to get coordinates
# attempting to get coordinates for M6A..........Failed to get coordinates
# attempting to get coordinates for M7A.
# attempting to get coordinates for M9A..........Failed to get coordinates
# attempting to get coordinates for M1B.
# attempting to get coordinates for M3B..........Failed to get coordinates
# attempting to get coordinates for M4B..........Failed to get coordinates
# attempting to get coordinates for M5B..........Failed to get coordinates
# attempting to get coordinates for M6B..........Failed to get coordinates
# attempting to get coordinates for M9B.
# attempting to get coordinates for M1C.
# attempting to get coordinates for M3C.
# attempting to get coordinates for M4C..........Failed to get coordinates
# attempting to get coordinates for M5C..........Failed to get coordinates
# attempting to get coordinates for M6C..........Failed to get coordinates
# attempting to get coordinates for M9C.
# attempting to get coordinates for M1E..........Failed to get coordinates
# attempting to get coordinates for M4E..........Failed to get coordinates
# attempting to get coordinates for M5E.
# attempting to get coordinates for M6E..........Failed to get coordinates
# attempting to get coordinates for M1G.
# attempting to get coordinates for M4G..........Failed to get coordinates
# attempting to get coordinates for M5G..........Failed to get coordinates
# attempting to get coordinates for M6G..........Failed to get coordinates
# attempting to get coordinates for M1H..........Failed to get coordinates
# attempting to get coordinates for M2H..........Failed to get coordinates
# attempting to get coordinates for M3H.
# attempting to get coordinates for M4H..........Failed to get coordinates
# attempting to get coordinates for M5H.
# attempting to get coordinates for M6H..........Failed to get coordinates
# attempting to get coordinates for M1J..........Failed to get coordinates
# attempting to get coordinates for M2J.
# attempting to get coordinates for M3J..........Failed to get coordinates
# attempting to get coordinates for M4J..........Failed to get coordinates
# attempting to get coordinates for M5J.
# attempting to get coordinates for M6J.
# attempting to get coordinates for M1K..........Failed to get coordinates
# attempting to get coordinates for M2K..........Failed to get coordinates
# attempting to get coordinates for M3K..........Failed to get coordinates
# attempting to get coordinates for M4K..........Failed to get coordinates
# attempting to get coordinates for M5K..........Failed to get coordinates
# attempting to get coordinates for M6K.
# attempting to get coordinates for M1L..........Failed to get coordinates
# attempting to get coordinates for M2L..........Failed to get coordinates
# attempting to get coordinates for M3L..........Failed to get coordinates
# attempting to get coordinates for M4L.
# attempting to get coordinates for M5L..........Failed to get coordinates
# attempting to get coordinates for M6L..........Failed to get coordinates
# attempting to get coordinates for M9L..........Failed to get coordinates
# attempting to get coordinates for M1M..........Failed to get coordinates
# attempting to get coordinates for M2M.
# attempting to get coordinates for M3M..........Failed to get coordinates
# attempting to get coordinates for M4M..........Failed to get coordinates
# attempting to get coordinates for M5M..........Failed to get coordinates
# attempting to get coordinates for M6M..........Failed to get coordinates
# attempting to get coordinates for M9M..........Failed to get coordinates
# attempting to get coordinates for M1N..........Failed to get coordinates
# attempting to get coordinates for M2N.
# attempting to get coordinates for M3N..........Failed to get coordinates
# attempting to get coordinates for M4N..........Failed to get coordinates
# attempting to get coordinates for M5N..........Failed to get coordinates
# attempting to get coordinates for M6N.
# attempting to get coordinates for M9N..........Failed to get coordinates
# attempting to get coordinates for M1P..........Failed to get coordinates
# attempting to get coordinates for M2P..........Failed to get coordinates
# attempting to get coordinates for M4P..........Failed to get coordinates
# attempting to get coordinates for M5P..........Failed to get coordinates
# attempting to get coordinates for M6P.
# attempting to get coordinates for M9P..........Failed to get coordinates
# attempting to get coordinates for M1R..........Failed to get coordinates
# attempting to get coordinates for M2R..........Failed to get coordinates
# attempting to get coordinates for M4R..........Failed to get coordinates
# attempting to get coordinates for M5R..........Failed to get coordinates
# attempting to get coordinates for M6R..........Failed to get coordinates
# attempting to get coordinates for M7R..........Failed to get coordinates
# attempting to get coordinates for M9R.
# attempting to get coordinates for M1S..........Failed to get coordinates
# attempting to get coordinates for M4S..........Failed to get coordinates
# attempting to get coordinates for M5S..........Failed to get coordinates
# attempting to get coordinates for M6S.
# attempting to get coordinates for M1T..........Failed to get coordinates
# attempting to get coordinates for M4T..........Failed to get coordinates
# attempting to get coordinates for M5T..........Failed to get coordinates
# attempting to get coordinates for M1V..........Failed to get coordinates
# attempting to get coordinates for M4V..........Failed to get coordinates
# attempting to get coordinates for M5V.
# attempting to get coordinates for M8V..........Failed to get coordinates
# attempting to get coordinates for M9V..........Failed to get coordinates
# attempting to get coordinates for M1W.
# attempting to get coordinates for M4W..........Failed to get coordinates
# attempting to get coordinates for M5W..........Failed to get coordinates
# attempting to get coordinates for M8W..........Failed to get coordinates
# attempting to get coordinates for M9W..........Failed to get coordinates
# attempting to get coordinates for M1X..........Failed to get coordinates
# attempting to get coordinates for M4X.
# attempting to get coordinates for M5X..........Failed to get coordinates
# attempting to get coordinates for M8X..........Failed to get coordinates
# attempting to get coordinates for M4Y..........Failed to get coordinates
# attempting to get coordinates for M7Y..........Failed to get coordinates
# attempting to get coordinates for M8Y..........Failed to get coordinates
# attempting to get coordinates for M8Z..........Failed to get coordinates

# %%
df_lat_lon = pd.DataFrame({'Postal Code':postal_codes, 'Latitude':latitudes,'Longitude':longitudes})
df_combined = pd.merge(df_filtered,df_lat_lon, on='Postal Code')
df_combined
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.653482 -79.383935
# 1                                     Victoria Village        NaN        NaN
# 2                            Regent Park, Harbourfront        NaN        NaN
# 3                     Lawrence Manor, Lawrence Heights        NaN        NaN
# 4          Queen's Park, Ontario Provincial Government  43.653482 -79.383935
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North        NaN        NaN
# 99                                Church and Wellesley        NaN        NaN
# 100  Business reply mail Processing Centre, South C...        NaN        NaN
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...        NaN        NaN
# 102  Mimico NW, The Queensway West, South of Bloor,...        NaN        NaN
#
# [103 rows x 5 columns]

# %% [markdown]
# That didn't work so well. So let's just get the geo coordinates from the web.

# %%
url = 'https://cocl.us/Geospatial_data'
csv = requests.get(url).content
df_lat_lon = pd.read_csv(io.StringIO(csv.decode('utf-8')))
df_combined = pd.merge(df_filtered,df_lat_lon, on='Postal Code')
df_combined = df_combined.rename(columns={'Postal Code':'PostalCode'})

# %% [markdown]
# ## Answer #2

# %%
df_combined
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# ..         ...               ...
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]
